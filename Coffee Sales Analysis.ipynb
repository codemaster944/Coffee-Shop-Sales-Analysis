# %%
import pandas as pd

df = pd.read_csv("index_1.csv")

# %%
df
# Out:
#             date                 datetime cash_type                 card  \
# 0     2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001
# 1     2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002
# 2     2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002
# 3     2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003
# 4     2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004
# ...          ...                      ...       ...                  ...
# 3631  2025-03-23  2025-03-23 10:34:54.894      card  ANON-0000-0000-1158
# 3632  2025-03-23  2025-03-23 14:43:37.362      card  ANON-0000-0000-1315
# 3633  2025-03-23  2025-03-23 14:44:16.864      card  ANON-0000-0000-1315
# 3634  2025-03-23  2025-03-23 15:47:28.723      card  ANON-0000-0000-1316
# 3635  2025-03-23  2025-03-23 18:11:38.635      card  ANON-0000-0000-1275
#
#       money    coffee_name
# 0     38.70          Latte
# 1     38.70  Hot Chocolate
# ...

# %%
df.head()
# Out:
#          date                 datetime cash_type                 card  money  \
# 0  2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001   38.7
# 1  2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002   38.7
# 2  2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002   38.7
# 3  2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003   28.9
# 4  2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004   38.7
#
#      coffee_name
# 0          Latte
# 1  Hot Chocolate
# 2  Hot Chocolate
# 3      Americano
# 4          Latte

# %%
df.tail()
# Out:
#             date                 datetime cash_type                 card  \
# 3631  2025-03-23  2025-03-23 10:34:54.894      card  ANON-0000-0000-1158
# 3632  2025-03-23  2025-03-23 14:43:37.362      card  ANON-0000-0000-1315
# 3633  2025-03-23  2025-03-23 14:44:16.864      card  ANON-0000-0000-1315
# 3634  2025-03-23  2025-03-23 15:47:28.723      card  ANON-0000-0000-1316
# 3635  2025-03-23  2025-03-23 18:11:38.635      card  ANON-0000-0000-1275
#
#       money coffee_name
# 3631  35.76  Cappuccino
# 3632  35.76       Cocoa
# 3633  35.76       Cocoa
# 3634  25.96   Americano
# 3635  35.76       Latte

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3636 entries, 0 to 3635
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3636 non-null   object
#  1   datetime     3636 non-null   object
#  2   cash_type    3636 non-null   object
#  3   card         3547 non-null   object
#  4   money        3636 non-null   float64
#  5   coffee_name  3636 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 170.6+ KB

# %%
df.count()
# Out:
# date           3636
# datetime       3636
# cash_type      3636
# card           3547
# money          3636
# coffee_name    3636
# dtype: int64

# %%
df.dtypes
# Out:
# date            object
# datetime        object
# cash_type       object
# card            object
# money          float64
# coffee_name     object
# dtype: object

# %%
df.std(numeric_only=True)
# Out:
# money    4.919926
# dtype: float64

# %%
df.describe()
# Out:
#              money
# count  3636.000000
# mean     31.746859
# std       4.919926
# min      18.120000
# 25%      27.920000
# 50%      32.820000
# 75%      35.760000
# max      40.000000

# %%
df.shape
# Out:
# (3636, 6)

# %%
df.isnull().sum()
# Out:
# date            0
# datetime        0
# cash_type       0
# card           89
# money           0
# coffee_name     0
# dtype: int64

# %%
# There is no null value on the card. The ones showing null are cash payments.

# %%
df[df["card"].isnull()]
# Out:
#            date                 datetime cash_type card  money  \
# 12   2024-03-02  2024-03-02 10:30:35.668      cash  NaN   40.0
# 18   2024-03-03  2024-03-03 10:10:43.981      cash  NaN   40.0
# 41   2024-03-06  2024-03-06 12:30:27.089      cash  NaN   35.0
# 46   2024-03-07  2024-03-07 10:08:58.945      cash  NaN   40.0
# 49   2024-03-07  2024-03-07 11:25:43.977      cash  NaN   40.0
# ..          ...                      ...       ...  ...    ...
# 657  2024-05-31  2024-05-31 09:23:58.791      cash  NaN   39.0
# 677  2024-06-01  2024-06-01 20:54:59.267      cash  NaN   39.0
# 685  2024-06-02  2024-06-02 22:43:10.636      cash  NaN   34.0
# 691  2024-06-03  2024-06-03 21:42:51.734      cash  NaN   34.0
# 692  2024-06-03  2024-06-03 21:43:37.471      cash  NaN   34.0
#
#              coffee_name
# 12                 Latte
# 18                 Latte
# 41   Americano with Milk
# 46                 Latte
# 49                 Latte
# ..                   ...
# ...

# %%
total_sales = df["money"].sum()

# %%
print("Total Sales:", total_sales)
# Out:
# Total Sales: 115431.58

# %%
payment_counts = df["cash_type"].value_counts()

# %%
print(payment_counts)
# Out:
# cash_type
# card    3547
# cash      89
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt


payment_counts.plot(kind="pie", figsize=(12,8), color=['#4A90E2', '#F5A623'])
plt.title("Number of Transactions by Payment Type")
plt.xlabel("Payment Type")
plt.ylabel("Number of Transactions")
plt.show()

# %%
sales_type = df.groupby("cash_type")["money"].sum()
print(sales_type)
# Out:
# cash_type
# card    112245.58
# cash      3186.00
# Name: money, dtype: float64

# %%
labels = ["Card", "Cash"]
values = [112245.58, 3186.00]

plt.figure(figsize=(10, 6))

plt.bar(labels, values, color=["#50E3C2", "#D0021B"])

plt.title("Card vs Cash Usage")
plt.ylabel("Total Money")
plt.xlabel("Sales card vs cash")
plt.show()

# %%
payment_counts.plot(kind="pie",figsize=(10,8),colors=['#4A90E2', '#F5A623'],autopct='%1.1f%%',)

plt.title("Percentage of Transactions by Payment Type")
plt.show()

# %%
df["coffee_name"].max()
# Out:
# 'Latte'

# %%
unique_coffee = df["coffee_name"].nunique()
print("How many types of coffee are there in total:", unique_coffee)
# Out:
# How many types of coffee are there in total: 8

# %%
coffee_list = df["coffee_name"].unique()
print("The names of coffee:", coffee_list)
# Out:
# The names of coffee: ['Latte' 'Hot Chocolate' 'Americano' 'Americano with Milk' 'Cocoa'
#  'Cortado' 'Espresso' 'Cappuccino']

# %%
coffee_counts = df["coffee_name"].value_counts()
print(coffee_counts)
# Out:
# coffee_name
# Americano with Milk    824
# Latte                  782
# Americano              578
# Cappuccino             501
# Cortado                292
# Hot Chocolate          282
# Cocoa                  243
# Espresso               134
# Name: count, dtype: int64

# %%
coffee_counts.plot(kind="barh", figsize=(10,6), color="skyblue")

plt.title("Number of Sales per Coffee Type")
plt.xlabel("Number of Sales") 
plt.ylabel("Coffee Name")       
plt.gca().invert_yaxis()        
plt.show()

# %%
top5_coffee = coffee_price.sort_values(ascending=False).head(5)
print(top5_coffee)
# Out:
# coffee_name
# Hot Chocolate          36.072553
# Cappuccino             35.996287
# Cocoa                  35.712593
# Latte                  35.634655
# Americano with Milk    30.666408
# Name: money, dtype: float64

# %%
coffee_sales = df.groupby("coffee_name")["money"].sum()
coffee_sales
# Out:
# coffee_name
# Americano              15062.26
# Americano with Milk    25269.12
# Cappuccino             18034.14
# Cocoa                   8678.16
# Cortado                 7534.86
# Espresso                2814.28
# Hot Chocolate          10172.46
# Latte                  27866.30
# Name: money, dtype: float64

# %%
top5_sales = coffee_sales.sort_values(ascending=False).head(5)
print(top5_sales)
# Out:
# coffee_name
# Latte                  27866.30
# Americano with Milk    25269.12
# Cappuccino             18034.14
# Americano              15062.26
# Hot Chocolate          10172.46
# Name: money, dtype: float64

# %%
colors = ["red", "blue", "orange", "purple", "cyan"]

top5_sales.plot(kind="bar", figsize=(8,6), color=colors)

plt.title("Top 5 Coffees by Total Sales")
plt.xlabel("Coffee Name")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.show()

# %%
df
# Out:
#             date                 datetime cash_type                 card  \
# 0     2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001
# 1     2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002
# 2     2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002
# 3     2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003
# 4     2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004
# ...          ...                      ...       ...                  ...
# 3631  2025-03-23  2025-03-23 10:34:54.894      card  ANON-0000-0000-1158
# 3632  2025-03-23  2025-03-23 14:43:37.362      card  ANON-0000-0000-1315
# 3633  2025-03-23  2025-03-23 14:44:16.864      card  ANON-0000-0000-1315
# 3634  2025-03-23  2025-03-23 15:47:28.723      card  ANON-0000-0000-1316
# 3635  2025-03-23  2025-03-23 18:11:38.635      card  ANON-0000-0000-1275
#
#       money    coffee_name
# 0     38.70          Latte
# 1     38.70  Hot Chocolate
# ...

# %%
average_spending = df['money'].mean()
print("Average Customer Spending:", round(average_spending, 2))
# Out:
# Average Customer Spending: 31.75
